# %% [markdown]
# <a href="https://colab.research.google.com/github/negar67/nshmp-haz/blob/master/NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #Pandas is used for easy indexing and data collection tools
import numpy as np # Numpy provides fast mathematical function processing
import re #Regular Expression is library used to make NLP process easier (patterns in text)
import nltk #Natural Language Toolkit is most powerful library for NLP 
import matplotlib.pyplot as plt
pd.options.display.max_colwidth = 200
# %matplotlib inline

# %%
data = pd.read_csv('/content/drive/My Drive/Colab Notebooks/train.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-bded7e662717> in <module>()
# ----> 1 data = pd.read_csv('/content/drive/My Drive/Colab Notebooks/train.csv')
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# ...

# %%
# !pip install PyDrive

# %%
import os
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
link = 'https://drive.google.com/open?id=1WESlvP-0bZNF-GaE2L0QjtfwG8j3W9yQ'
fluff, id = link.split('=')

# %%
print(id)
# Out:
# 1WESlvP-0bZNF-GaE2L0QjtfwG8j3W9yQ

# %%
downloaded = drive.CreateFile({'id':id})
downloaded.GetContentFile('train.csv')

# %%
data = pd.read_csv('train.csv')

# %%
data.head()
# Out:
#       id    target  ... identity_annotator_count  toxicity_annotator_count
# 0  59848  0.000000  ...                        0                         4
# 1  59849  0.000000  ...                        0                         4
# 2  59852  0.000000  ...                        0                         4
# 3  59855  0.000000  ...                        0                         4
# 4  59856  0.893617  ...                        4                        47
#
# [5 rows x 45 columns]

# %%
data.shape
# Out:
# (1804874, 45)

# %%
data['toxic'] = (np.where(data.target>0.5,1,0))
print(np.where(data.target>0.5,1,0))
# Out:
# [0 0 0 ... 0 1 0]

# %%
print(data.target>0.5)
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4           True
#            ...
# 1804869    False
# 1804870    False
# 1804871    False
# 1804872     True
# 1804873    False
# Name: target, Length: 1804874, dtype: bool

# %%
data.toxic.value_counts()
# Out:
# 0    1698436
# 1     106438
# Name: toxic, dtype: int64

# %%
corpus = data.comment_text[0:100]

# %%
corpus
# Out:
# 0                                                                                                       This is so cool. It's like, 'would you want your mother to read this??' Really great idea, well done!
# 1                                                                                          Thank you!! This would make my life a lot less anxiety-inducing. Keep it up, and don't let anyone get in your way!
# 2                                                                                                                      This is such an urgent design problem; kudos to you for taking it on. Very impressive!
# 3                                                                                                                        Is this something I'll be able to install on my site? When will you be releasing it?
# ...

# %%
pd.options.display.max_rows = 999

# %%
corpus
# Out:
# 0                                                                                                       This is so cool. It's like, 'would you want your mother to read this??' Really great idea, well done!
# 1                                                                                          Thank you!! This would make my life a lot less anxiety-inducing. Keep it up, and don't let anyone get in your way!
# 2                                                                                                                      This is such an urgent design problem; kudos to you for taking it on. Very impressive!
# 3                                                                                                                        Is this something I'll be able to install on my site? When will you be releasing it?
# ...

# %%
labels = data.toxic[0:100]

# %%
corpus = np.array(corpus)

corpus_df = pd.DataFrame({'Document' : corpus,
                          'Category' : labels})
corpus_df = corpus_df[['Document', 'Category']]
corpus_df
# Out:
#                                                                                                                                                                                                    Document  Category
# 0                                                                                                     This is so cool. It's like, 'would you want your mother to read this??' Really great idea, well done!         0
# 1                                                                                        Thank you!! This would make my life a lot less anxiety-inducing. Keep it up, and don't let anyone get in your way!         0
# 2                                                                                                                    This is such an urgent design problem; kudos to you for taking it on. Very impressive!         0
# ...
